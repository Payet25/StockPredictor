# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2010-01-01",end ="2023-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Apple
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-01-04 00:00:00-05:00    7.622500    7.660714    7.585000    7.643214
# 2010-01-05 00:00:00-05:00    7.664286    7.699643    7.616071    7.656429
# 2010-01-06 00:00:00-05:00    7.656429    7.686786    7.526786    7.534643
# 2010-01-07 00:00:00-05:00    7.562500    7.571429    7.466071    7.520714
# 2010-01-08 00:00:00-05:00    7.510714    7.571429    7.466429    7.570714
# ...                               ...         ...         ...         ...
# 2022-12-23 00:00:00-05:00  130.919998  132.419998  129.639999  131.860001
# 2022-12-27 00:00:00-05:00  131.380005  131.410004  128.720001  130.029999
# 2022-12-28 00:00:00-05:00  129.669998  131.029999  125.870003  126.040001
# 2022-12-29 00:00:00-05:00  127.989998  130.479996  127.730003  129.610001
# 2022-12-30 00:00:00-05:00  128.410004  129.949997  127.430000  129.929993
#
#                             Adj Close     Volume
# Date
# 2010-01-04 00:00:00-05:00    6.505280  493729600
# 2010-01-05 00:00:00-05:00    6.516529  601904800
# 2010-01-06 00:00:00-05:00    6.412873  552160000
# 2010-01-07 00:00:00-05:00    6.401018  477131200
# 2010-01-08 00:00:00-05:00    6.443573  447610800
# ...                               ...        ...
# 2022-12-23 00:00:00-05:00  131.658981   63814900
# 2022-12-27 00:00:00-05:00  129.831772   69007800
# 2022-12-28 00:00:00-05:00  125.847855   85438400
# 2022-12-29 00:00:00-05:00  129.412415   75703700
# 2022-12-30 00:00:00-05:00  129.731918   77034200
#
# [3272 rows x 6 columns]

# %%
ticker = ["SPY","AAPL","KO"]

# %%
stocks = yf.download(ticker, start = "2010-01-01",end ="2023-01-01")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
stocks
# Out:
#                             Adj Close                              Close  \
#                                  AAPL         KO         SPY        AAPL
# Date
# 2010-01-04 00:00:00-05:00    6.505280  18.936371   88.117882    7.643214
# 2010-01-05 00:00:00-05:00    6.516529  18.707296   88.351151    7.656429
# 2010-01-06 00:00:00-05:00    6.412873  18.700663   88.413361    7.534643
# 2010-01-07 00:00:00-05:00    6.401018  18.654179   88.786560    7.520714
# 2010-01-08 00:00:00-05:00    6.443575  18.308914   89.082069    7.570714
# ...                               ...        ...         ...         ...
# 2022-12-23 00:00:00-05:00  131.658981  63.334194  381.454193  131.860001
# 2022-12-27 00:00:00-05:00  129.831772  63.721226  379.949921  130.029999
# 2022-12-28 00:00:00-05:00  125.847855  63.086098  375.227936  126.040001
# 2022-12-29 00:00:00-05:00  129.412415  63.463207  381.982178  129.610001
# 2022-12-30 00:00:00-05:00  129.731918  63.125793  380.975983  129.929993
#
#                                                         High             \
#                                   KO         SPY        AAPL         KO
# Date
# 2010-01-04 00:00:00-05:00  28.520000  113.330002    7.660714  28.610001
# 2010-01-05 00:00:00-05:00  28.174999  113.629997    7.699643  28.495001
# 2010-01-06 00:00:00-05:00  28.165001  113.709999    7.686786  28.219999
# 2010-01-07 00:00:00-05:00  28.094999  114.190002    7.571429  28.184999
# 2010-01-08 00:00:00-05:00  27.575001  114.570000    7.571429  27.820000
# ...                              ...         ...         ...        ...
# 2022-12-23 00:00:00-05:00  63.820000  382.910004  132.419998  63.869999
# 2022-12-27 00:00:00-05:00  64.209999  381.399994  131.410004  64.290001
# 2022-12-28 00:00:00-05:00  63.570000  376.660004  131.029999  64.650002
# 2022-12-29 00:00:00-05:00  63.950001  383.440002  130.479996  64.150002
# 2022-12-30 00:00:00-05:00  63.610001  382.429993  129.949997  63.919998
#
#                                               Low                         \
#                                   SPY        AAPL         KO         SPY
# Date
# 2010-01-04 00:00:00-05:00  113.389999    7.585000  28.450001  111.510002
# 2010-01-05 00:00:00-05:00  113.680000    7.616071  28.070000  112.849998
# 2010-01-06 00:00:00-05:00  113.989998    7.526786  27.990000  113.430000
# 2010-01-07 00:00:00-05:00  114.330002    7.466071  27.875000  113.180000
# 2010-01-08 00:00:00-05:00  114.620003    7.466429  27.375000  113.660004
# ...                               ...         ...        ...         ...
# 2022-12-23 00:00:00-05:00  383.059998  129.639999  63.200001  378.029999
# 2022-12-27 00:00:00-05:00  383.149994  128.720001  63.709999  379.649994
# 2022-12-28 00:00:00-05:00  383.390015  125.870003  63.490002  376.420013
# 2022-12-29 00:00:00-05:00  384.350006  127.730003  63.700001  379.079987
# 2022-12-30 00:00:00-05:00  382.579987  127.430000  63.169998  378.429993
#
#                                  Open                            Volume  \
#                                  AAPL         KO         SPY       AAPL
# Date
# 2010-01-04 00:00:00-05:00    7.622500  28.580000  112.370003  493729600
# 2010-01-05 00:00:00-05:00    7.664286  28.424999  113.260002  601904800
# 2010-01-06 00:00:00-05:00    7.656429  28.174999  113.519997  552160000
# 2010-01-07 00:00:00-05:00    7.562500  28.165001  113.500000  477131200
# 2010-01-08 00:00:00-05:00    7.510714  27.730000  113.889999  447610800
# ...                               ...        ...         ...        ...
# 2022-12-23 00:00:00-05:00  130.919998  63.500000  379.649994   63814900
# 2022-12-27 00:00:00-05:00  131.380005  63.930000  382.790009   69007800
# 2022-12-28 00:00:00-05:00  129.669998  64.459999  381.329987   85438400
# 2022-12-29 00:00:00-05:00  127.989998  63.799999  379.630005   75703700
# 2022-12-30 00:00:00-05:00  128.410004  63.919998  380.640015   77034200
#
#
#                                  KO        SPY
# Date
# 2010-01-04 00:00:00-05:00  13870400  118944600
# 2010-01-05 00:00:00-05:00  23172400  111579900
# 2010-01-06 00:00:00-05:00  19264600  116074400
# 2010-01-07 00:00:00-05:00  13234600  131091100
# 2010-01-08 00:00:00-05:00  28712400  126402800
# ...                             ...        ...
# 2022-12-23 00:00:00-05:00   6463300   59857300
# 2022-12-27 00:00:00-05:00   7320700   51638200
# 2022-12-28 00:00:00-05:00   7159400   70911500
# 2022-12-29 00:00:00-05:00   7169300   66970900
# 2022-12-30 00:00:00-05:00   7650200   84022200
#
# [3272 rows x 18 columns]

# %%
stocks.head()
# Out:
#                           Adj Close                           Close  \
#                                AAPL         KO        SPY      AAPL
# Date
# 2010-01-04 00:00:00-05:00  6.505280  18.936371  88.117882  7.643214
# 2010-01-05 00:00:00-05:00  6.516529  18.707296  88.351151  7.656429
# 2010-01-06 00:00:00-05:00  6.412873  18.700663  88.413361  7.534643
# 2010-01-07 00:00:00-05:00  6.401018  18.654179  88.786560  7.520714
# 2010-01-08 00:00:00-05:00  6.443575  18.308914  89.082069  7.570714
#
#                                                       High             \
#                                   KO         SPY      AAPL         KO
# Date
# 2010-01-04 00:00:00-05:00  28.520000  113.330002  7.660714  28.610001
# 2010-01-05 00:00:00-05:00  28.174999  113.629997  7.699643  28.495001
# 2010-01-06 00:00:00-05:00  28.165001  113.709999  7.686786  28.219999
# 2010-01-07 00:00:00-05:00  28.094999  114.190002  7.571429  28.184999
# 2010-01-08 00:00:00-05:00  27.575001  114.570000  7.571429  27.820000
#
#                                             Low                         \
#                                   SPY      AAPL         KO         SPY
# Date
# 2010-01-04 00:00:00-05:00  113.389999  7.585000  28.450001  111.510002
# 2010-01-05 00:00:00-05:00  113.680000  7.616071  28.070000  112.849998
# 2010-01-06 00:00:00-05:00  113.989998  7.526786  27.990000  113.430000
# 2010-01-07 00:00:00-05:00  114.330002  7.466071  27.875000  113.180000
# 2010-01-08 00:00:00-05:00  114.620003  7.466429  27.375000  113.660004
#
#                                Open                            Volume  \
#                                AAPL         KO         SPY       AAPL
# Date
# 2010-01-04 00:00:00-05:00  7.622500  28.580000  112.370003  493729600
# 2010-01-05 00:00:00-05:00  7.664286  28.424999  113.260002  601904800
# 2010-01-06 00:00:00-05:00  7.656429  28.174999  113.519997  552160000
# 2010-01-07 00:00:00-05:00  7.562500  28.165001  113.500000  477131200
# 2010-01-08 00:00:00-05:00  7.510714  27.730000  113.889999  447610800
#
#
#                                  KO        SPY
# Date
# 2010-01-04 00:00:00-05:00  13870400  118944600
# 2010-01-05 00:00:00-05:00  23172400  111579900
# 2010-01-06 00:00:00-05:00  19264600  116074400
# 2010-01-07 00:00:00-05:00  13234600  131091100
# 2010-01-08 00:00:00-05:00  28712400  126402800

# %%
stocks.tail()
# Out:
#                             Adj Close                              Close  \
#                                  AAPL         KO         SPY        AAPL
# Date
# 2022-12-23 00:00:00-05:00  131.658981  63.334194  381.454193  131.860001
# 2022-12-27 00:00:00-05:00  129.831772  63.721226  379.949921  130.029999
# 2022-12-28 00:00:00-05:00  125.847855  63.086098  375.227936  126.040001
# 2022-12-29 00:00:00-05:00  129.412415  63.463207  381.982178  129.610001
# 2022-12-30 00:00:00-05:00  129.731918  63.125793  380.975983  129.929993
#
#                                                         High             \
#                                   KO         SPY        AAPL         KO
# Date
# 2022-12-23 00:00:00-05:00  63.820000  382.910004  132.419998  63.869999
# 2022-12-27 00:00:00-05:00  64.209999  381.399994  131.410004  64.290001
# 2022-12-28 00:00:00-05:00  63.570000  376.660004  131.029999  64.650002
# 2022-12-29 00:00:00-05:00  63.950001  383.440002  130.479996  64.150002
# 2022-12-30 00:00:00-05:00  63.610001  382.429993  129.949997  63.919998
#
#                                               Low                         \
#                                   SPY        AAPL         KO         SPY
# Date
# 2022-12-23 00:00:00-05:00  383.059998  129.639999  63.200001  378.029999
# 2022-12-27 00:00:00-05:00  383.149994  128.720001  63.709999  379.649994
# 2022-12-28 00:00:00-05:00  383.390015  125.870003  63.490002  376.420013
# 2022-12-29 00:00:00-05:00  384.350006  127.730003  63.700001  379.079987
# 2022-12-30 00:00:00-05:00  382.579987  127.430000  63.169998  378.429993
#
#                                  Open                           Volume  \
#                                  AAPL         KO         SPY      AAPL
# Date
# 2022-12-23 00:00:00-05:00  130.919998  63.500000  379.649994  63814900
# 2022-12-27 00:00:00-05:00  131.380005  63.930000  382.790009  69007800
# 2022-12-28 00:00:00-05:00  129.669998  64.459999  381.329987  85438400
# 2022-12-29 00:00:00-05:00  127.989998  63.799999  379.630005  75703700
# 2022-12-30 00:00:00-05:00  128.410004  63.919998  380.640015  77034200
#
#
#                                 KO       SPY
# Date
# 2022-12-23 00:00:00-05:00  6463300  59857300
# 2022-12-27 00:00:00-05:00  7320700  51638200
# 2022-12-28 00:00:00-05:00  7159400  70911500
# 2022-12-29 00:00:00-05:00  7169300  66970900
# 2022-12-30 00:00:00-05:00  7650200  84022200

# %%
stocks.to_csv("stocksyt.csv")

# %%
stocks = pd.read_csv("stocksyt.csv")

# %%
stocks
# Out:
#                      Unnamed: 0           Adj Close         Adj Close.1  \
# 0                           NaN                AAPL                  KO
# 1                          Date                 NaN                 NaN
# 2     2010-01-04 00:00:00-05:00   6.505280494689941  18.936370849609375
# 3     2010-01-05 00:00:00-05:00   6.516528606414795   18.70729637145996
# 4     2010-01-06 00:00:00-05:00   6.412872791290283   18.70066261291504
# ...                         ...                 ...                 ...
# 3269  2022-12-23 00:00:00-05:00   131.6589813232422   63.33419418334961
# 3270  2022-12-27 00:00:00-05:00  129.83177185058594   63.72122573852539
# 3271  2022-12-28 00:00:00-05:00  125.84785461425781  63.086097717285156
# 3272  2022-12-29 00:00:00-05:00  129.41241455078125   63.46320724487305
# 3273  2022-12-30 00:00:00-05:00  129.73191833496094   63.12579345703125
#
#             Adj Close.2               Close             Close.1  \
# 0                   SPY                AAPL                  KO
# 1                   NaN                 NaN                 NaN
# 2     88.11788177490234   7.643214225769043  28.520000457763672
# 3     88.35115051269531   7.656428813934326  28.174999237060547
# 4     88.41336059570312   7.534643173217773  28.165000915527344
# ...                 ...                 ...                 ...
# 3269  381.4541931152344  131.86000061035156   63.81999969482422
# 3270  379.9499206542969  130.02999877929688   64.20999908447266
# 3271  375.2279357910156  126.04000091552734   63.56999969482422
# 3272   381.982177734375  129.61000061035156   63.95000076293945
# 3273  380.9759826660156  129.92999267578125   63.61000061035156
#
#                  Close.2                High              High.1  \
# 0                    SPY                AAPL                  KO
# 1                    NaN                 NaN                 NaN
# 2     113.33000183105469   7.660714149475098  28.610000610351562
# 3     113.62999725341797   7.699643135070801    28.4950008392334
# 4     113.70999908447266    7.68678617477417  28.219999313354492
# ...                  ...                 ...                 ...
# 3269   382.9100036621094   132.4199981689453  63.869998931884766
# 3270   381.3999938964844  131.41000366210938   64.29000091552734
# 3271   376.6600036621094  131.02999877929688    64.6500015258789
# 3272  383.44000244140625  130.47999572753906    64.1500015258789
# 3273  382.42999267578125   129.9499969482422   63.91999816894531
#
#                   High.2                 Low               Low.1  \
# 0                    SPY                AAPL                  KO
# 1                    NaN                 NaN                 NaN
# 2     113.38999938964844   7.585000038146973  28.450000762939453
# 3     113.68000030517578  7.6160712242126465   28.06999969482422
# 4     113.98999786376953   7.526785850524902  27.989999771118164
# ...                  ...                 ...                 ...
# 3269  383.05999755859375  129.63999938964844   63.20000076293945
# 3270   383.1499938964844  128.72000122070312  63.709999084472656
# 3271   383.3900146484375  125.87000274658203    63.4900016784668
# 3272   384.3500061035156   127.7300033569336   63.70000076293945
# 3273   382.5799865722656  127.43000030517578   63.16999816894531
#
#                    Low.2                Open              Open.1  \
# 0                    SPY                AAPL                  KO
# 1                    NaN                 NaN                 NaN
# 2     111.51000213623047   7.622499942779541  28.579999923706055
# 3      112.8499984741211   7.664286136627197  28.424999237060547
# 4     113.43000030517578   7.656428813934326  28.174999237060547
# ...                  ...                 ...                 ...
# 3269   378.0299987792969   130.9199981689453                63.5
# 3270   379.6499938964844   131.3800048828125   63.93000030517578
# 3271   376.4200134277344   129.6699981689453   64.45999908447266
# 3272   379.0799865722656  127.98999786376953   63.79999923706055
# 3273  378.42999267578125  128.41000366210938   63.91999816894531
#
#                   Open.2     Volume  Volume.1   Volume.2
# 0                    SPY       AAPL        KO        SPY
# 1                    NaN        NaN       NaN        NaN
# 2     112.37000274658203  493729600  13870400  118944600
# 3     113.26000213623047  601904800  23172400  111579900
# 4      113.5199966430664  552160000  19264600  116074400
# ...                  ...        ...       ...        ...
# 3269   379.6499938964844   63814900   6463300   59857300
# 3270   382.7900085449219   69007800   7320700   51638200
# 3271   381.3299865722656   85438400   7159400   70911500
# 3272   379.6300048828125   75703700   7169300   66970900
# 3273   380.6400146484375   77034200   7650200   84022200
#
# [3274 rows x 19 columns]

# %%
stocks = pd.read_csv("stocksyt.csv",header=[0,1])
stocks
# Out:
#              Unnamed: 0_level_0   Adj Close                         \
#              Unnamed: 0_level_1        AAPL         KO         SPY
# 0                          Date         NaN        NaN         NaN
# 1     2010-01-04 00:00:00-05:00    6.505280  18.936371   88.117882
# 2     2010-01-05 00:00:00-05:00    6.516529  18.707296   88.351151
# 3     2010-01-06 00:00:00-05:00    6.412873  18.700663   88.413361
# 4     2010-01-07 00:00:00-05:00    6.401018  18.654179   88.786560
# ...                         ...         ...        ...         ...
# 3268  2022-12-23 00:00:00-05:00  131.658981  63.334194  381.454193
# 3269  2022-12-27 00:00:00-05:00  129.831772  63.721226  379.949921
# 3270  2022-12-28 00:00:00-05:00  125.847855  63.086098  375.227936
# 3271  2022-12-29 00:00:00-05:00  129.412415  63.463207  381.982178
# 3272  2022-12-30 00:00:00-05:00  129.731918  63.125793  380.975983
#
#            Close                               High                         \
#             AAPL         KO         SPY        AAPL         KO         SPY
# 0            NaN        NaN         NaN         NaN        NaN         NaN
# 1       7.643214  28.520000  113.330002    7.660714  28.610001  113.389999
# 2       7.656429  28.174999  113.629997    7.699643  28.495001  113.680000
# 3       7.534643  28.165001  113.709999    7.686786  28.219999  113.989998
# 4       7.520714  28.094999  114.190002    7.571429  28.184999  114.330002
# ...          ...        ...         ...         ...        ...         ...
# 3268  131.860001  63.820000  382.910004  132.419998  63.869999  383.059998
# 3269  130.029999  64.209999  381.399994  131.410004  64.290001  383.149994
# 3270  126.040001  63.570000  376.660004  131.029999  64.650002  383.390015
# 3271  129.610001  63.950001  383.440002  130.479996  64.150002  384.350006
# 3272  129.929993  63.610001  382.429993  129.949997  63.919998  382.579987
#
#              Low                               Open                         \
#             AAPL         KO         SPY        AAPL         KO         SPY
# 0            NaN        NaN         NaN         NaN        NaN         NaN
# 1       7.585000  28.450001  111.510002    7.622500  28.580000  112.370003
# 2       7.616071  28.070000  112.849998    7.664286  28.424999  113.260002
# 3       7.526786  27.990000  113.430000    7.656429  28.174999  113.519997
# 4       7.466071  27.875000  113.180000    7.562500  28.165001  113.500000
# ...          ...        ...         ...         ...        ...         ...
# 3268  129.639999  63.200001  378.029999  130.919998  63.500000  379.649994
# 3269  128.720001  63.709999  379.649994  131.380005  63.930000  382.790009
# 3270  125.870003  63.490002  376.420013  129.669998  64.459999  381.329987
# 3271  127.730003  63.700001  379.079987  127.989998  63.799999  379.630005
# 3272  127.430000  63.169998  378.429993  128.410004  63.919998  380.640015
#
#            Volume
#              AAPL          KO          SPY
# 0             NaN         NaN          NaN
# 1     493729600.0  13870400.0  118944600.0
# 2     601904800.0  23172400.0  111579900.0
# 3     552160000.0  19264600.0  116074400.0
# 4     477131200.0  13234600.0  131091100.0
# ...           ...         ...          ...
# 3268   63814900.0   6463300.0   59857300.0
# 3269   69007800.0   7320700.0   51638200.0
# 3270   85438400.0   7159400.0   70911500.0
# 3271   75703700.0   7169300.0   66970900.0
# 3272   77034200.0   7650200.0   84022200.0
#
# [3273 rows x 19 columns]

# %%
stocks = pd.read_csv("stocksyt.csv",header=[0,1], index_col=[0])
stocks
# Out:
#                             Adj Close                              Close  \
#                                  AAPL         KO         SPY        AAPL
# Date
# 2010-01-04 00:00:00-05:00    6.505280  18.936371   88.117882    7.643214
# 2010-01-05 00:00:00-05:00    6.516529  18.707296   88.351151    7.656429
# 2010-01-06 00:00:00-05:00    6.412873  18.700663   88.413361    7.534643
# 2010-01-07 00:00:00-05:00    6.401018  18.654179   88.786560    7.520714
# 2010-01-08 00:00:00-05:00    6.443575  18.308914   89.082069    7.570714
# ...                               ...        ...         ...         ...
# 2022-12-23 00:00:00-05:00  131.658981  63.334194  381.454193  131.860001
# 2022-12-27 00:00:00-05:00  129.831772  63.721226  379.949921  130.029999
# 2022-12-28 00:00:00-05:00  125.847855  63.086098  375.227936  126.040001
# 2022-12-29 00:00:00-05:00  129.412415  63.463207  381.982178  129.610001
# 2022-12-30 00:00:00-05:00  129.731918  63.125793  380.975983  129.929993
#
#                                                         High             \
#                                   KO         SPY        AAPL         KO
# Date
# 2010-01-04 00:00:00-05:00  28.520000  113.330002    7.660714  28.610001
# 2010-01-05 00:00:00-05:00  28.174999  113.629997    7.699643  28.495001
# 2010-01-06 00:00:00-05:00  28.165001  113.709999    7.686786  28.219999
# 2010-01-07 00:00:00-05:00  28.094999  114.190002    7.571429  28.184999
# 2010-01-08 00:00:00-05:00  27.575001  114.570000    7.571429  27.820000
# ...                              ...         ...         ...        ...
# 2022-12-23 00:00:00-05:00  63.820000  382.910004  132.419998  63.869999
# 2022-12-27 00:00:00-05:00  64.209999  381.399994  131.410004  64.290001
# 2022-12-28 00:00:00-05:00  63.570000  376.660004  131.029999  64.650002
# 2022-12-29 00:00:00-05:00  63.950001  383.440002  130.479996  64.150002
# 2022-12-30 00:00:00-05:00  63.610001  382.429993  129.949997  63.919998
#
#                                               Low                         \
#                                   SPY        AAPL         KO         SPY
# Date
# 2010-01-04 00:00:00-05:00  113.389999    7.585000  28.450001  111.510002
# 2010-01-05 00:00:00-05:00  113.680000    7.616071  28.070000  112.849998
# 2010-01-06 00:00:00-05:00  113.989998    7.526786  27.990000  113.430000
# 2010-01-07 00:00:00-05:00  114.330002    7.466071  27.875000  113.180000
# 2010-01-08 00:00:00-05:00  114.620003    7.466429  27.375000  113.660004
# ...                               ...         ...        ...         ...
# 2022-12-23 00:00:00-05:00  383.059998  129.639999  63.200001  378.029999
# 2022-12-27 00:00:00-05:00  383.149994  128.720001  63.709999  379.649994
# 2022-12-28 00:00:00-05:00  383.390015  125.870003  63.490002  376.420013
# 2022-12-29 00:00:00-05:00  384.350006  127.730003  63.700001  379.079987
# 2022-12-30 00:00:00-05:00  382.579987  127.430000  63.169998  378.429993
#
#                                  Open                            Volume  \
#                                  AAPL         KO         SPY       AAPL
# Date
# 2010-01-04 00:00:00-05:00    7.622500  28.580000  112.370003  493729600
# 2010-01-05 00:00:00-05:00    7.664286  28.424999  113.260002  601904800
# 2010-01-06 00:00:00-05:00    7.656429  28.174999  113.519997  552160000
# 2010-01-07 00:00:00-05:00    7.562500  28.165001  113.500000  477131200
# 2010-01-08 00:00:00-05:00    7.510714  27.730000  113.889999  447610800
# ...                               ...        ...         ...        ...
# 2022-12-23 00:00:00-05:00  130.919998  63.500000  379.649994   63814900
# 2022-12-27 00:00:00-05:00  131.380005  63.930000  382.790009   69007800
# 2022-12-28 00:00:00-05:00  129.669998  64.459999  381.329987   85438400
# 2022-12-29 00:00:00-05:00  127.989998  63.799999  379.630005   75703700
# 2022-12-30 00:00:00-05:00  128.410004  63.919998  380.640015   77034200
#
#
#                                  KO        SPY
# Date
# 2010-01-04 00:00:00-05:00  13870400  118944600
# 2010-01-05 00:00:00-05:00  23172400  111579900
# 2010-01-06 00:00:00-05:00  19264600  116074400
# 2010-01-07 00:00:00-05:00  13234600  131091100
# 2010-01-08 00:00:00-05:00  28712400  126402800
# ...                             ...        ...
# 2022-12-23 00:00:00-05:00   6463300   59857300
# 2022-12-27 00:00:00-05:00   7320700   51638200
# 2022-12-28 00:00:00-05:00   7159400   70911500
# 2022-12-29 00:00:00-05:00   7169300   66970900
# 2022-12-30 00:00:00-05:00   7650200   84022200
#
# [3272 rows x 18 columns]

# %%
stocks = pd.read_csv("stocksyt.csv",header=[0,1], index_col=[0], parse_dates=[0])
stocks
# Out:
#                             Adj Close                              Close  \
#                                  AAPL         KO         SPY        AAPL
# Date
# 2010-01-04 00:00:00-05:00    6.505280  18.936371   88.117882    7.643214
# 2010-01-05 00:00:00-05:00    6.516529  18.707296   88.351151    7.656429
# 2010-01-06 00:00:00-05:00    6.412873  18.700663   88.413361    7.534643
# 2010-01-07 00:00:00-05:00    6.401018  18.654179   88.786560    7.520714
# 2010-01-08 00:00:00-05:00    6.443575  18.308914   89.082069    7.570714
# ...                               ...        ...         ...         ...
# 2022-12-23 00:00:00-05:00  131.658981  63.334194  381.454193  131.860001
# 2022-12-27 00:00:00-05:00  129.831772  63.721226  379.949921  130.029999
# 2022-12-28 00:00:00-05:00  125.847855  63.086098  375.227936  126.040001
# 2022-12-29 00:00:00-05:00  129.412415  63.463207  381.982178  129.610001
# 2022-12-30 00:00:00-05:00  129.731918  63.125793  380.975983  129.929993
#
#                                                         High             \
#                                   KO         SPY        AAPL         KO
# Date
# 2010-01-04 00:00:00-05:00  28.520000  113.330002    7.660714  28.610001
# 2010-01-05 00:00:00-05:00  28.174999  113.629997    7.699643  28.495001
# 2010-01-06 00:00:00-05:00  28.165001  113.709999    7.686786  28.219999
# 2010-01-07 00:00:00-05:00  28.094999  114.190002    7.571429  28.184999
# 2010-01-08 00:00:00-05:00  27.575001  114.570000    7.571429  27.820000
# ...                              ...         ...         ...        ...
# 2022-12-23 00:00:00-05:00  63.820000  382.910004  132.419998  63.869999
# 2022-12-27 00:00:00-05:00  64.209999  381.399994  131.410004  64.290001
# 2022-12-28 00:00:00-05:00  63.570000  376.660004  131.029999  64.650002
# 2022-12-29 00:00:00-05:00  63.950001  383.440002  130.479996  64.150002
# 2022-12-30 00:00:00-05:00  63.610001  382.429993  129.949997  63.919998
#
#                                               Low                         \
#                                   SPY        AAPL         KO         SPY
# Date
# 2010-01-04 00:00:00-05:00  113.389999    7.585000  28.450001  111.510002
# 2010-01-05 00:00:00-05:00  113.680000    7.616071  28.070000  112.849998
# 2010-01-06 00:00:00-05:00  113.989998    7.526786  27.990000  113.430000
# 2010-01-07 00:00:00-05:00  114.330002    7.466071  27.875000  113.180000
# 2010-01-08 00:00:00-05:00  114.620003    7.466429  27.375000  113.660004
# ...                               ...         ...        ...         ...
# 2022-12-23 00:00:00-05:00  383.059998  129.639999  63.200001  378.029999
# 2022-12-27 00:00:00-05:00  383.149994  128.720001  63.709999  379.649994
# 2022-12-28 00:00:00-05:00  383.390015  125.870003  63.490002  376.420013
# 2022-12-29 00:00:00-05:00  384.350006  127.730003  63.700001  379.079987
# 2022-12-30 00:00:00-05:00  382.579987  127.430000  63.169998  378.429993
#
#                                  Open                            Volume  \
#                                  AAPL         KO         SPY       AAPL
# Date
# 2010-01-04 00:00:00-05:00    7.622500  28.580000  112.370003  493729600
# 2010-01-05 00:00:00-05:00    7.664286  28.424999  113.260002  601904800
# 2010-01-06 00:00:00-05:00    7.656429  28.174999  113.519997  552160000
# 2010-01-07 00:00:00-05:00    7.562500  28.165001  113.500000  477131200
# 2010-01-08 00:00:00-05:00    7.510714  27.730000  113.889999  447610800
# ...                               ...        ...         ...        ...
# 2022-12-23 00:00:00-05:00  130.919998  63.500000  379.649994   63814900
# 2022-12-27 00:00:00-05:00  131.380005  63.930000  382.790009   69007800
# 2022-12-28 00:00:00-05:00  129.669998  64.459999  381.329987   85438400
# 2022-12-29 00:00:00-05:00  127.989998  63.799999  379.630005   75703700
# 2022-12-30 00:00:00-05:00  128.410004  63.919998  380.640015   77034200
#
#
#                                  KO        SPY
# Date
# 2010-01-04 00:00:00-05:00  13870400  118944600
# 2010-01-05 00:00:00-05:00  23172400  111579900
# 2010-01-06 00:00:00-05:00  19264600  116074400
# 2010-01-07 00:00:00-05:00  13234600  131091100
# 2010-01-08 00:00:00-05:00  28712400  126402800
# ...                             ...        ...
# 2022-12-23 00:00:00-05:00   6463300   59857300
# 2022-12-27 00:00:00-05:00   7320700   51638200
# 2022-12-28 00:00:00-05:00   7159400   70911500
# 2022-12-29 00:00:00-05:00   7169300   66970900
# 2022-12-30 00:00:00-05:00   7650200   84022200
#
# [3272 rows x 18 columns]

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  3272.000000  3272.000000  3272.000000  3272.000000  3272.000000
# mean     49.394303    36.471608   218.689552    51.321186    43.864995
# std      47.751071    11.444698   104.476187    47.357062     8.837265
# min       5.837760    16.761831    80.170799     6.858929    25.014999
# 25%      16.600969    28.219790   129.683815    18.967589    38.520000
# 50%      27.344625    34.374737   186.444878    29.815000    42.730000
# 75%      54.869687    43.799581   275.349434    56.777499    48.882499
# max     180.683868    64.306442   468.296417   182.009995    66.209999
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  3272.000000  3272.000000  3272.000000  3272.000000  3272.000000
# mean    239.951657    51.869747    44.153762   241.249994    50.731996
# std      98.496748    47.938843     8.917754    99.147238    46.732224
# min     102.199997     7.000000    25.150000   103.419998     6.794643
# 25%     156.139999    19.121697    38.754999   156.484997    18.780179
# 50%     212.509995    29.981250    43.065001   212.985001    29.561250
# 75%     293.064995    57.309999    49.310001   294.164993    56.469999
# max     477.709991   182.940002    67.199997   479.980011   179.119995
#
#                                         Open                            \
#                 KO          SPY         AAPL           KO          SPY
# count  3272.000000  3272.000000  3272.000000  3272.000000  3272.000000
# mean     43.561964   238.462317    51.297746    43.860524   239.923478
# std       8.754691    97.785640    47.328490     8.836552    98.509133
# min      24.735001   101.129997     6.870357    25.110001   103.110001
# 25%      38.279999   155.252495    18.966697    38.560001   156.069996
# 50%      42.440001   211.635002    29.756250    42.730000   212.349998
# 75%      48.529999   291.345009    56.983748    48.784999   292.877502
# max      65.720001   476.059998   182.630005    67.000000   479.220001
#
#              Volume
#                AAPL            KO           SPY
# count  3.272000e+03  3.272000e+03  3.272000e+03
# mean   2.562707e+08  1.516091e+07  1.182773e+08
# std    2.225648e+08  6.725716e+06  7.140215e+07
# min    3.519590e+07  2.996300e+06  2.027000e+07
# 25%    1.023541e+08  1.084798e+07  6.995998e+07
# 50%    1.666698e+08  1.365555e+07  9.882665e+07
# 75%    3.456643e+08  1.762438e+07  1.451754e+08
# max    1.880998e+09  9.896750e+07  7.178287e+08

# %%
close=stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                                  AAPL         KO         SPY
# Date
# 2010-01-04 00:00:00-05:00    7.643214  28.520000  113.330002
# 2010-01-05 00:00:00-05:00    7.656429  28.174999  113.629997
# 2010-01-06 00:00:00-05:00    7.534643  28.165001  113.709999
# 2010-01-07 00:00:00-05:00    7.520714  28.094999  114.190002
# 2010-01-08 00:00:00-05:00    7.570714  27.575001  114.570000
# ...                               ...        ...         ...
# 2022-12-23 00:00:00-05:00  131.860001  63.820000  382.910004
# 2022-12-27 00:00:00-05:00  130.029999  64.209999  381.399994
# 2022-12-28 00:00:00-05:00  126.040001  63.570000  376.660004
# 2022-12-29 00:00:00-05:00  129.610001  63.950001  383.440002
# 2022-12-30 00:00:00-05:00  129.929993  63.610001  382.429993
#
# [3272 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close.plot(figsize=(15,8),fontsize=12)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL
# Out:
# Date
# 2010-01-04 00:00:00-05:00      7.643214
# 2010-01-05 00:00:00-05:00      7.656429
# 2010-01-06 00:00:00-05:00      7.534643
# 2010-01-07 00:00:00-05:00      7.520714
# 2010-01-08 00:00:00-05:00      7.570714
#                                 ...
# 2022-12-23 00:00:00-05:00    131.860001
# 2022-12-27 00:00:00-05:00    130.029999
# 2022-12-28 00:00:00-05:00    126.040001
# 2022-12-29 00:00:00-05:00    129.610001
# 2022-12-30 00:00:00-05:00    129.929993
# Name: AAPL, Length: 3272, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04 00:00:00-05:00     1.000000
# 2010-01-05 00:00:00-05:00     1.001729
# 2010-01-06 00:00:00-05:00     0.985795
# 2010-01-07 00:00:00-05:00     0.983973
# 2010-01-08 00:00:00-05:00     0.990514
#                                ...
# 2022-12-23 00:00:00-05:00    17.251904
# 2022-12-27 00:00:00-05:00    17.012476
# 2022-12-28 00:00:00-05:00    16.490445
# 2022-12-29 00:00:00-05:00    16.957526
# 2022-12-30 00:00:00-05:00    16.999392
# Name: AAPL, Length: 3272, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04 00:00:00-05:00     100.000000
# 2010-01-05 00:00:00-05:00     100.172893
# 2010-01-06 00:00:00-05:00      98.579511
# 2010-01-07 00:00:00-05:00      98.397266
# 2010-01-08 00:00:00-05:00      99.051443
#                                 ...
# 2022-12-23 00:00:00-05:00    1725.190433
# 2022-12-27 00:00:00-05:00    1701.247603
# 2022-12-28 00:00:00-05:00    1649.044462
# 2022-12-29 00:00:00-05:00    1695.752556
# 2022-12-30 00:00:00-05:00    1699.939173
# Name: AAPL, Length: 3272, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# SPY     113.330002
# Name: 2010-01-04 00:00:00-05:00, dtype: float64

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
aapl= close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                                  AAPL
# Date
# 2010-01-04 00:00:00-05:00    7.643214
# 2010-01-05 00:00:00-05:00    7.656429
# 2010-01-06 00:00:00-05:00    7.534643
# 2010-01-07 00:00:00-05:00    7.520714
# 2010-01-08 00:00:00-05:00    7.570714
# ...                               ...
# 2022-12-23 00:00:00-05:00  131.860001
# 2022-12-27 00:00:00-05:00  130.029999
# 2022-12-28 00:00:00-05:00  126.040001
# 2022-12-29 00:00:00-05:00  129.610001
# 2022-12-30 00:00:00-05:00  129.929993
#
# [3272 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                                  AAPL
# Date
# 2010-01-04 00:00:00-05:00         NaN
# 2010-01-05 00:00:00-05:00    7.643214
# 2010-01-06 00:00:00-05:00    7.656429
# 2010-01-07 00:00:00-05:00    7.534643
# 2010-01-08 00:00:00-05:00    7.520714
# ...                               ...
# 2022-12-23 00:00:00-05:00  132.229996
# 2022-12-27 00:00:00-05:00  131.860001
# 2022-12-28 00:00:00-05:00  130.029999
# 2022-12-29 00:00:00-05:00  126.040001
# 2022-12-30 00:00:00-05:00  129.610001
#
# [3272 rows x 1 columns]

# %%
aapl["lag1"]=aapl.shift(periods=1)

# %%
aapl
# Out:
#                                  AAPL        lag1
# Date
# 2010-01-04 00:00:00-05:00    7.643214         NaN
# 2010-01-05 00:00:00-05:00    7.656429    7.643214
# 2010-01-06 00:00:00-05:00    7.534643    7.656429
# 2010-01-07 00:00:00-05:00    7.520714    7.534643
# 2010-01-08 00:00:00-05:00    7.570714    7.520714
# ...                               ...         ...
# 2022-12-23 00:00:00-05:00  131.860001  132.229996
# 2022-12-27 00:00:00-05:00  130.029999  131.860001
# 2022-12-28 00:00:00-05:00  126.040001  130.029999
# 2022-12-29 00:00:00-05:00  129.610001  126.040001
# 2022-12-30 00:00:00-05:00  129.929993  129.610001
#
# [3272 rows x 2 columns]

# %%
aapl.AAPL.sub(aapl.lag1)
# Out:
# Date
# 2010-01-04 00:00:00-05:00         NaN
# 2010-01-05 00:00:00-05:00    0.013215
# 2010-01-06 00:00:00-05:00   -0.121786
# 2010-01-07 00:00:00-05:00   -0.013929
# 2010-01-08 00:00:00-05:00    0.050000
#                                ...
# 2022-12-23 00:00:00-05:00   -0.369995
# 2022-12-27 00:00:00-05:00   -1.830002
# 2022-12-28 00:00:00-05:00   -3.989998
# 2022-12-29 00:00:00-05:00    3.570000
# 2022-12-30 00:00:00-05:00    0.319992
# Length: 3272, dtype: float64

# %%
aapl
# Out:
#                                  AAPL        lag1
# Date
# 2010-01-04 00:00:00-05:00    7.643214         NaN
# 2010-01-05 00:00:00-05:00    7.656429    7.643214
# 2010-01-06 00:00:00-05:00    7.534643    7.656429
# 2010-01-07 00:00:00-05:00    7.520714    7.534643
# 2010-01-08 00:00:00-05:00    7.570714    7.520714
# ...                               ...         ...
# 2022-12-23 00:00:00-05:00  131.860001  132.229996
# 2022-12-27 00:00:00-05:00  130.029999  131.860001
# 2022-12-28 00:00:00-05:00  126.040001  130.029999
# 2022-12-29 00:00:00-05:00  129.610001  126.040001
# 2022-12-30 00:00:00-05:00  129.929993  129.610001
#
# [3272 rows x 2 columns]

# %%
aapl["Diff"]=aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                                  AAPL        lag1      Diff
# Date
# 2010-01-04 00:00:00-05:00    7.643214         NaN       NaN
# 2010-01-05 00:00:00-05:00    7.656429    7.643214  0.013215
# 2010-01-06 00:00:00-05:00    7.534643    7.656429 -0.121786
# 2010-01-07 00:00:00-05:00    7.520714    7.534643 -0.013929
# 2010-01-08 00:00:00-05:00    7.570714    7.520714  0.050000
# ...                               ...         ...       ...
# 2022-12-23 00:00:00-05:00  131.860001  132.229996 -0.369995
# 2022-12-27 00:00:00-05:00  130.029999  131.860001 -1.830002
# 2022-12-28 00:00:00-05:00  126.040001  130.029999 -3.989998
# 2022-12-29 00:00:00-05:00  129.610001  126.040001  3.570000
# 2022-12-30 00:00:00-05:00  129.929993  129.610001  0.319992
#
# [3272 rows x 3 columns]

# %%
aapl.AAPL.div(aapl.lag1)
# Out:
# Date
# 2010-01-04 00:00:00-05:00         NaN
# 2010-01-05 00:00:00-05:00    1.001729
# 2010-01-06 00:00:00-05:00    0.984094
# 2010-01-07 00:00:00-05:00    0.998151
# 2010-01-08 00:00:00-05:00    1.006648
#                                ...
# 2022-12-23 00:00:00-05:00    0.997202
# 2022-12-27 00:00:00-05:00    0.986122
# 2022-12-28 00:00:00-05:00    0.969315
# 2022-12-29 00:00:00-05:00    1.028324
# 2022-12-30 00:00:00-05:00    1.002469
# Length: 3272, dtype: float64

# %%
aapl["% change"]=aapl.AAPL.div(aapl.lag1)

# %%
aapl
# Out:
#                                  AAPL        lag1      Diff  % change
# Date
# 2010-01-04 00:00:00-05:00    7.643214         NaN       NaN       NaN
# 2010-01-05 00:00:00-05:00    7.656429    7.643214  0.013215  1.001729
# 2010-01-06 00:00:00-05:00    7.534643    7.656429 -0.121786  0.984094
# 2010-01-07 00:00:00-05:00    7.520714    7.534643 -0.013929  0.998151
# 2010-01-08 00:00:00-05:00    7.570714    7.520714  0.050000  1.006648
# ...                               ...         ...       ...       ...
# 2022-12-23 00:00:00-05:00  131.860001  132.229996 -0.369995  0.997202
# 2022-12-27 00:00:00-05:00  130.029999  131.860001 -1.830002  0.986122
# 2022-12-28 00:00:00-05:00  126.040001  130.029999 -3.989998  0.969315
# 2022-12-29 00:00:00-05:00  129.610001  126.040001  3.570000  1.028324
# 2022-12-30 00:00:00-05:00  129.929993  129.610001  0.319992  1.002469
#
# [3272 rows x 4 columns]

# %%
del aapl["lag1"]

# %%
del aapl["Diff"]
aapl
# Out:
#                                  AAPL  % change
# Date
# 2010-01-04 00:00:00-05:00    7.643214       NaN
# 2010-01-05 00:00:00-05:00    7.656429  1.001729
# 2010-01-06 00:00:00-05:00    7.534643  0.984094
# 2010-01-07 00:00:00-05:00    7.520714  0.998151
# 2010-01-08 00:00:00-05:00    7.570714  1.006648
# ...                               ...       ...
# 2022-12-23 00:00:00-05:00  131.860001  0.997202
# 2022-12-27 00:00:00-05:00  130.029999  0.986122
# 2022-12-28 00:00:00-05:00  126.040001  0.969315
# 2022-12-29 00:00:00-05:00  129.610001  1.028324
# 2022-12-30 00:00:00-05:00  129.929993  1.002469
#
# [3272 rows x 2 columns]

# %%
aapl.rename(columns = {'% change': 'Change'}, inplace =True)

# %%
aapl
# Out:
#                                  AAPL    Change
# Date
# 2010-01-04 00:00:00-05:00    7.643214       NaN
# 2010-01-05 00:00:00-05:00    7.656429  1.001729
# 2010-01-06 00:00:00-05:00    7.534643  0.984094
# 2010-01-07 00:00:00-05:00    7.520714  0.998151
# 2010-01-08 00:00:00-05:00    7.570714  1.006648
# ...                               ...       ...
# 2022-12-23 00:00:00-05:00  131.860001  0.997202
# 2022-12-27 00:00:00-05:00  130.029999  0.986122
# 2022-12-28 00:00:00-05:00  126.040001  0.969315
# 2022-12-29 00:00:00-05:00  129.610001  1.028324
# 2022-12-30 00:00:00-05:00  129.929993  1.002469
#
# [3272 rows x 2 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3270 entries, 2010-01-06 00:00:00-05:00 to 2022-12-30 00:00:00-05:00
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3270 non-null   float64
#  1   Change  3270 non-null   float64
# dtypes: float64(2)
# memory usage: 76.6+ KB

# %%
aapl
# Out:
#                                  AAPL    Change
# Date
# 2010-01-04 00:00:00-05:00    7.643214       NaN
# 2010-01-05 00:00:00-05:00    7.656429  1.001729
# 2010-01-06 00:00:00-05:00    7.534643  0.984094
# 2010-01-07 00:00:00-05:00    7.520714  0.998151
# 2010-01-08 00:00:00-05:00    7.570714  1.006648
# ...                               ...       ...
# 2022-12-23 00:00:00-05:00  131.860001  0.997202
# 2022-12-27 00:00:00-05:00  130.029999  0.986122
# 2022-12-28 00:00:00-05:00  126.040001  0.969315
# 2022-12-29 00:00:00-05:00  129.610001  1.028324
# 2022-12-30 00:00:00-05:00  129.929993  1.002469
#
# [3272 rows x 2 columns]

# %%
ret.plot(kind="hist", figsize=(12,8), bins=100)
plt.show()

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# AAPL      0.001030
# Change    0.000344
# dtype: float64

# %%
var_daily=ret.var()
var_daily
# Out:
# AAPL      0.000328
# Change    0.000692
# dtype: float64

# %%
std_daily=np.sqrt(var_daily)
std_daily
# Out:
# AAPL      0.018102
# Change    0.026311
# dtype: float64

# %%
ret.std()
# Out:
# AAPL      0.018102
# Change    0.026311
# dtype: float64

# %%
annual_mean_ret=daily_mean_ret+252
annual_mean_ret
# Out:
# AAPL      252.001030
# Change    252.000344
# dtype: float64

# %%
annual_var_ret=var_daily+252
annual_var_ret
# Out:
# AAPL      252.000328
# Change    252.000692
# dtype: float64

# %%
annual_std_returns=np.sqrt(annual_var_ret)
annual_std_returns
# Out:
# AAPL      15.874518
# Change    15.874530
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL      0.287361
# Change    0.417667
# dtype: float64

# %%
tickers=["SPY","AAPL","KD","IBM","DIS","MSFT"]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3270 entries, 2010-01-06 00:00:00-05:00 to 2022-12-30 00:00:00-05:00
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3270 non-null   float64
#  1   Change  3270 non-null   float64
# dtypes: float64(2)
# memory usage: 76.6+ KB

# %%
ret.plot(kind="hist",figsize=(12,8), bins=100)
plt.show()

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# AAPL      0.001030
# Change    0.000344
# dtype: float64

# %%
var_daily=ret.var()
var_daily
# Out:
# AAPL      0.000328
# Change    0.000692
# dtype: float64

# %%
std_daily=np.sqrt(var_daily)

# %%
std_daily
# Out:
# AAPL      0.018102
# Change    0.026311
# dtype: float64

# %%
ret.std()
# Out:
# AAPL      0.018102
# Change    0.026311
# dtype: float64

# %%
annual_mean_ret=daily_mean_ret*252
annual_mean_ret
# Out:
# AAPL      0.259609
# Change    0.086717
# dtype: float64

# %%
annual_var_ret=var_daily*252
annual_var_ret
# Out:
# AAPL      0.082576
# Change    0.174446
# dtype: float64

# %%
annual_std_returns=np.sqrt(annual_var_ret)
annual_std_returns
# Out:
# AAPL      0.287361
# Change    0.417667
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL      0.287361
# Change    0.417667
# dtype: float64

# %%
ticker = ["SPY","AAPL","KO","IBM","DIS","MSFT"]

# %%
stocks = yf.download(ticker, start = "2010-01-01",end ="2023-01-01")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
close=stocks.loc[:,"Close"].copy()

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
#                                AAPL       DIS       IBM        KO      MSFT  \
# Date
# 2010-01-05 00:00:00-05:00  0.001729 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 00:00:00-05:00 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 00:00:00-05:00 -0.001849  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08 00:00:00-05:00  0.006648  0.001571  0.010035 -0.018509  0.006897
# 2010-01-11 00:00:00-05:00 -0.008821 -0.016311 -0.010470  0.020308 -0.012720
#
#                                 SPY
# Date
# 2010-01-05 00:00:00-05:00  0.002647
# 2010-01-06 00:00:00-05:00  0.000704
# 2010-01-07 00:00:00-05:00  0.004221
# 2010-01-08 00:00:00-05:00  0.003328
# 2010-01-11 00:00:00-05:00  0.001397

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  3271.0  0.001030  0.018099 -0.128647 -0.007652  0.000865  0.010640
# DIS   3271.0  0.000440  0.016435 -0.131632 -0.006798  0.000427  0.008040
# IBM   3271.0  0.000135  0.014255 -0.128507 -0.006398  0.000326  0.007037
# KO    3271.0  0.000307  0.011097 -0.096725 -0.004747  0.000488  0.005900
# MSFT  3271.0  0.000760  0.016392 -0.147390 -0.007240  0.000534  0.009028
# SPY   3271.0  0.000434  0.011132 -0.109424 -0.003830  0.000595  0.005689
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# SPY   0.090603

# %%
summary=ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#           mean       std
# AAPL  0.001030  0.018099
# DIS   0.000440  0.016435
# IBM   0.000135  0.014255
# KO    0.000307  0.011097
# MSFT  0.000760  0.016392
# SPY   0.000434  0.011132

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.259663  0.287317
# DIS   0.110785  0.260902
# IBM   0.033968  0.226295
# KO    0.077394  0.176152
# MSFT  0.191645  0.260214
# SPY   0.109393  0.176719

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
    plt.xlabel("Annual risk(std)",fontsize=15)
    plt.ylabel("Annual return",fontsize=15)
    plt.title("Risk/return",fontsize=15)

# %%
ret.cov()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000328  0.000126  0.000107  0.000071  0.000177  0.000139
# DIS   0.000126  0.000270  0.000106  0.000084  0.000131  0.000128
# IBM   0.000107  0.000106  0.000203  0.000077  0.000114  0.000104
# KO    0.000071  0.000084  0.000077  0.000123  0.000078  0.000077
# MSFT  0.000177  0.000131  0.000114  0.000078  0.000269  0.000139
# SPY   0.000139  0.000128  0.000104  0.000077  0.000139  0.000124

# %%
ret.corr()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.424060  0.415156  0.352489  0.595650  0.689343
# DIS   0.424060  1.000000  0.450761  0.461784  0.486882  0.700196
# IBM   0.415156  0.450761  1.000000  0.486299  0.485986  0.657488
# KO    0.352489  0.461784  0.486299  1.000000  0.426982  0.623916
# MSFT  0.595650  0.486882  0.485986  0.426982  1.000000  0.762329
# SPY   0.689343  0.700196  0.657488  0.623916  0.762329  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95],columns=["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns=df.pct_change().dropna()

# %%
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
logreturns=np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy=SPY.Close

# %%
spy
# Out:
# Date
# 1993-01-29 00:00:00-05:00     43.937500
# 1993-02-01 00:00:00-05:00     44.250000
# 1993-02-02 00:00:00-05:00     44.343750
# 1993-02-03 00:00:00-05:00     44.812500
# 1993-02-04 00:00:00-05:00     45.000000
#                                 ...
# 2023-04-10 00:00:00-04:00    409.609985
# 2023-04-11 00:00:00-04:00    409.720001
# 2023-04-12 00:00:00-04:00    408.049988
# 2023-04-13 00:00:00-04:00    413.470001
# 2023-04-14 00:00:00-04:00    410.630005
# Name: Close, Length: 7607, dtype: float64

# %%
spy=SPY.Close.to_frame()

# %%
spy
# Out:
#                                 Close
# Date
# 1993-01-29 00:00:00-05:00   43.937500
# 1993-02-01 00:00:00-05:00   44.250000
# 1993-02-02 00:00:00-05:00   44.343750
# 1993-02-03 00:00:00-05:00   44.812500
# 1993-02-04 00:00:00-05:00   45.000000
# ...                               ...
# 2023-04-10 00:00:00-04:00  409.609985
# 2023-04-11 00:00:00-04:00  409.720001
# 2023-04-12 00:00:00-04:00  408.049988
# 2023-04-13 00:00:00-04:00  413.470001
# 2023-04-14 00:00:00-04:00  410.630005
#
# [7607 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy_roll=spy.rolling(window=10)
spy_roll
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
spy_roll=spy_roll.mean()
spy_roll
# Out:
#                                 Close
# Date
# 1993-01-29 00:00:00-05:00         NaN
# 1993-02-01 00:00:00-05:00         NaN
# 1993-02-02 00:00:00-05:00         NaN
# 1993-02-03 00:00:00-05:00         NaN
# 1993-02-04 00:00:00-05:00         NaN
# ...                               ...
# 2023-04-10 00:00:00-04:00  405.255005
# 2023-04-11 00:00:00-04:00  406.578006
# 2023-04-12 00:00:00-04:00  407.823004
# 2023-04-13 00:00:00-04:00  409.035004
# 2023-04-14 00:00:00-04:00  409.728003
#
# [7607 rows x 1 columns]
